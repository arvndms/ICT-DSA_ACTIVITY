# %% [markdown]
# <a href="https://colab.research.google.com/github/arvndms/ICT-DSA_ACTIVITY/blob/main/panda_%26_numpy_usecase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy

# %% [markdown]
# Library

# %%
import numpy as np
import pandas as pd

# %%
data = np.genfromtxt( 'auto-mpg (1).csv',delimiter=',',skip_header=1)

# %%
df = pd.read_csv('auto-mpg (1).csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# Convert the mpg column into a NumPy array and calculate:
# ○ The mean, median, and standard deviation of mpg.
# ○ The number of cars with mpg greater than 25.

# %%
mpg_array = np.array(data[:,0])
mean = np.nanmean(mpg_array) #it has null values in it
median = np.nanmedian(mpg_array)
sd = np.nanstd(mpg_array)
print(mean,median,sd)
# Out:
# 23.514572864321607 23.0 7.806159061274433

# %%
count = np.sum(data[:,0]>25)
print(count)
# Out:
# 158

# %% [markdown]
# Using NumPy, filter all cars with more than 6 cylinders.
# Return the corresponding car_name as a list

# %%
cylinders = df['cylinders'].values > 6
car_names = df['car name'].values

# %%
six_cylinder_cars_filtered = car_names[cylinders]
final_car_list =six_cylinder_cars_filtered.tolist()
print(final_car_list)
# Out:
# ['chevrolet chevelle malibu', 'buick skylark 320', 'plymouth satellite', 'amc rebel sst', 'ford torino', 'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii', 'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se', "plymouth 'cuda 340", 'chevrolet monte carlo', 'buick estate wagon (sw)', 'ford f250', 'chevy c20', 'dodge d200', 'hi 1200d', 'chevrolet impala', 'pontiac catalina brougham', 'ford galaxie 500', 'plymouth fury iii', 'dodge monaco (sw)', 'ford country squire (sw)', 'pontiac safari (sw)', 'chevrolet impala', 'pontiac catalina', 'plymouth fury iii', 'ford galaxie 500', 'amc ambassador sst', 'mercury marquis', 'buick lesabre custom', 'oldsmobile delta 88 royale', 'chrysler newport royal', 'amc matador (sw)', 'chevrolet chevelle concours (sw)', 'ford gran torino (sw)', 'plymouth satellite custom (sw)', 'buick century 350', 'amc matador', 'chevrolet malibu', 'ford gran torino', 'dodge coronet custom', 'mercury marquis brougham', 'chevrolet caprice classic', 'ford
# ...

# %% [markdown]
# Compute the 25th, 50th, and 75th percentiles of the weight column using NumPy.

# %%
weight = data[:,4]

# %%
percent_25 = np.nanpercentile(weight,25)
percent_50 = np.nanpercentile(weight,50)
percent_75 = np.nanpercentile(weight,75)

# %%
print(percent_25,percent_50,percent_75)
# Out:
# 2223.75 2803.5 3608.0

# %% [markdown]
# Array Manipulation
# Convert the acceleration column into a NumPy array and normalize its values
# (scale between 0 and 1).

# %%
acceleration_array = np.array(df['acceleration'])
'''
Normalized Value=​X−Xmin/Xmax​−Xmin
'''
acc_min_value = np.nanmin(acceleration_array)
acc_max_value = np.nanmax(acceleration_array)
normalized_acceleration =(acceleration_array-acc_min_value)/(acc_max_value-acc_min_value)
print(normalized_acceleration)
# Out:
# [0.23809524 0.20833333 0.17857143 0.23809524 0.14880952 0.11904762
#  0.05952381 0.0297619  0.11904762 0.0297619  0.11904762 0.
#  0.08928571 0.11904762 0.41666667 0.44642857 0.44642857 0.47619048
#  0.38690476 0.74404762 0.56547619 0.38690476 0.56547619 0.26785714
#  0.41666667 0.35714286 0.41666667 0.32738095 0.625      0.38690476
#  0.44642857 0.35714286 0.6547619  0.29761905 0.44642857 0.44642857
#  0.44642857 0.44642857 0.23809524 0.20833333 0.32738095 0.29761905
#  0.20833333 0.23809524 0.23809524 0.32738095 0.6547619  0.41666667
#  0.38690476 0.35714286 0.35714286 0.68452381 0.38690476 0.6547619
#  0.5952381  0.6547619  0.74404762 0.44642857 0.53571429 0.92261905
#  0.68452381 0.50595238 0.23809524 0.23809524 0.32738095 0.29761905
#  0.20833333 0.17857143 0.32738095 0.32738095 0.26785714 0.32738095
#  0.26785714 0.35714286 0.47619048 0.35714286 0.38690476 0.5952381
#  0.68452381 0.5952381  0.47619048 0.53571429 0.38690476 0.41666667
# ...

# %% [markdown]
# Broadcasting
# Increase all horsepower values by 10% and store the updated values in a new
# NumPy array. Handle missing data (if any) by replacing it with the mean of the
# column before applying the increase.

# %%
hp_mean = np.nanmean(data[:,3])
horsepower = np.nan_to_num(data[:,3],nan=hp_mean)
updated_hp = horsepower*1.10
print(updated_hp)
# Out:
# [143.         181.5        165.         165.         154.
#  217.8        242.         236.5        247.5        209.
#  187.         176.         165.         247.5        104.5
#  104.5        106.7         93.5         96.8         50.6
#   95.7         99.         104.5        124.3         99.
#  236.5        220.         231.         212.3         96.8
#   99.         104.5        114.91632653 110.         115.5
#  110.          96.8        110.         181.5        192.5
#  168.3        165.         198.         187.         192.5
#  121.          79.2        110.          96.8         94.6
#   99.          77.          83.6         71.5         75.9
#   66.          77.         104.5         88.          59.4
#   99.          94.6        181.5        192.5        165.
#  168.3        165.         228.8        170.5        176.
#  209.         106.7        165.         143.         154.
#  165.         123.2         83.6         95.7         75.9
# ...

# %% [markdown]
# Boolean Indexing
# Find the average displacement of cars with an origin of 2 (Europe) using NumPy
# indexing.

# %%
europe_cars = data[data[:,7]==2]
displacement_erp_cars = europe_cars[:,2]
mean_displacement = np.nanmean(displacement_erp_cars)
print(mean_displacement)
# Out:
# 109.14285714285714

# %% [markdown]
#  Matrix Operations
# Create a 2D NumPy array containing the columns mpg, horsepower, and weight.
# Compute the dot product of this matrix with a given vector [1, 0.5, -0.2].

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mean())
vector = np.array([1,0.5,-0.2])
mpg_hp_wgt_array = df[['mpg' , 'horsepower' , 'weight']].values
# for dot product
dot_product = np.dot(mpg_hp_wgt_array,vector)
print(dot_product)
# Out:
# [-617.8        -641.1        -594.2        -595.6        -602.8
#  -754.2        -746.8        -740.9        -758.5        -660.
#  -612.6        -627.8        -662.2        -490.7        -402.9
#  -497.1        -488.3        -453.9        -355.         -318.
#  -465.9        -417.         -402.5        -364.3        -463.6
#  -805.5        -765.2        -760.4        -840.9        -355.
#  -379.8        -373.1        -331.96530612 -457.8        -619.3
#  -598.8        -597.4        -589.6        -745.3        -791.3
#  -740.3        -730.2        -889.         -851.2        -927.5
#  -519.4        -423.6        -587.4        -565.8        -378.
#  -351.6        -349.8        -345.         -291.1        -253.1
#  -309.8        -330.         -384.1        -360.2        -400.8
#  -416.6        -381.2        -759.3        -775.5        -737.
#  -735.3        -642.4        -811.6        -809.9        -799.2
#  -776.4        -398.5        -688.4        -741.6        -775.8
# ...

# %% [markdown]
#  Sorting
# Use NumPy to sort the cars by model_year in descending order and display the first
# five car names.

# %%
model_year = np.array(df['model year'])
desc_model_year = np.argsort(model_year)[::-1]
car_name = np.array(df['car name'])
five_car_names = car_name[desc_model_year][:5]
print(five_car_names)
# Out:
# ['dodge aries se' 'pontiac phoenix' 'pontiac j2000 se hatchback'
#  'chevrolet cavalier 2-door' 'chevrolet cavalier wagon']

# %% [markdown]
#  Correlation
# Compute the Pearson correlation coefficient between mpg and weight using
# NumPy.

# %%
mpg = np.array(df['mpg'])
weight = np.array(df['weight'])
correlation = np.corrcoef(mpg,weight)[0,1]
print(correlation)
# Out:
# -0.8317409332443352

# %% [markdown]
# Calculate the mean mpg for cars grouped by the number of cylinders using NumPy
# techniques.

# %%
mpg_values = np.array(df['mpg'])
cylinders = np.array(df['cylinders'])
unique_cylinders = np.unique(cylinders)
for cyl in unique_cylinders:
   mean_mpg_values=np.mean(mpg_values[cylinders==cyl])
   print(f'Cylinders: {cyl}, Mean MPG: {mean_mpg_values}')
# Out:
# Cylinders: 3, Mean MPG: 20.55
# Cylinders: 4, Mean MPG: 29.28676470588235
# Cylinders: 5, Mean MPG: 27.366666666666664
# Cylinders: 6, Mean MPG: 19.985714285714284
# Cylinders: 8, Mean MPG: 14.963106796116506

# %% [markdown]
# # Pandas

# %% [markdown]
# Load the dataset into a Pandas DataFrame. Display:
# ○ The first 10 rows
# ○ The total number of rows and columns
# ○ Summary statistics for numerical columns

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# ...

# %%
print('Number of rows and columns',df.shape)
# Out:
# Number of rows and columns (398, 9)

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  398.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.199187   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   76.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   95.000000  2803.500000
# 75%     29.000000    8.000000    262.000000  125.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# Find all cars manufactured in 1975 with a weight less than 3000. Return the
# DataFrame with selected columns: car_name, weight, and mpg.

# %%
filtered_cars = df[(df['model year'] == 75) & (df['weight'] < 3000)]
car_filtered_list = filtered_cars[['car name','weight','mpg']]
print(car_filtered_list)
# Out:
#               car name  weight   mpg
# 167     toyota corolla    2171  29.0
# 168         ford pinto    2639  23.0
# 169        amc gremlin    2914  20.0
# 170      pontiac astro    2592  23.0
# 171      toyota corona    2702  24.0
# 172  volkswagen dasher    2223  25.0
# 173         datsun 710    2545  24.0
# 174         ford pinto    2984  18.0
# 175  volkswagen rabbit    1937  29.0
# 177         audi 100ls    2694  23.0
# 178        peugeot 504    2957  23.0
# 179        volvo 244dl    2945  22.0
# 180          saab 99le    2671  25.0
# 181   honda civic cvcc    1795  33.0

# %% [markdown]
#  Handling Missing Data
# Identify if there are any missing values in the dataset. Replace missing values in the
# horsepower column with the column's median.

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
median_hp = df['horsepower'].median()
df['horsepower'] = df['horsepower'].fillna(median_hp)
print(df['horsepower'].isnull().sum())
# Out:
# 0

# %% [markdown]
# Add a new column power_to_weight_ratio, calculated as horsepower / weight.

# %%
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df['weight'] = df['weight'].fillna(df['weight'].median())

# %%
df['power_to_weight'] = df['horsepower']/df['weight']
print(df['power_to_weight'])
# Out:
# 0      0.037100
# 1      0.044679
# 2      0.043655
# 3      0.043694
# 4      0.040591
#          ...
# 393    0.030824
# 394    0.024413
# 395    0.036601
# 396    0.030095
# 397    0.030147
# Name: power_to_weight, Length: 398, dtype: float64

# %% [markdown]
# Group the cars by origin and calculate the mean mpg for each group.

# %%
mpg_origin = df.groupby('origin')['mpg'].mean()
mpg_origin
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %% [markdown]
# Sort the DataFrame by mpg in descending order and display the top 10 cars with
# the highest mpg.

# %%
desc_highmpg_cars = df.sort_values(by='mpg',ascending=False)
desc_highmpg_cars.head(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0   65.000000    2110          17.9
# 329  44.6          4          91.0   67.000000    1850          13.8
# 325  44.3          4          90.0   48.000000    2085          21.7
# 394  44.0          4          97.0   52.000000    2130          24.6
# 326  43.4          4          90.0   48.000000    2335          23.7
# 244  43.1          4          90.0   48.000000    1985          21.5
# 309  41.5          4          98.0   76.000000    2144          14.7
# 330  40.9          4          85.0  104.469388    1835          17.3
# 324  40.8          4          85.0   65.000000    2110          19.2
# 247  39.4          4          85.0   70.000000    2070          18.6
#
#      model year  origin                         car name  power_to_weight
# 322          80       3                        mazda glc         0.030806
# ...

# %% [markdown]
# Create a new column performance_score using a custom function:
# def performance_score(row):
# return row['mpg'] * row['acceleration'] / row['weight']

# %%
def performance_score(row):
    return row['mpg'] * row['acceleration'] / row['weight']

# %% [markdown]
# Apply this function to each row and store the result in the new column

# %%
df['perfomance score'] = df.apply(performance_score,axis=1)
df[['car name' ,'perfomance score']]
# Out:
#                       car name  perfomance score
# 0    chevrolet chevelle malibu          0.061644
# 1            buick skylark 320          0.046710
# 2           plymouth satellite          0.057625
# 3                amc rebel sst          0.055928
# 4                  ford torino          0.051754
# ..                         ...               ...
# 393            ford mustang gl          0.150968
# 394                  vw pickup          0.508169
# 395              dodge rampage          0.161743
# 396                ford ranger          0.198400
# 397                 chevy s-10          0.221103
#
# [398 rows x 2 columns]

# %% [markdown]
#  Visualization Preparation
# Generate a summary DataFrame with:
# ○ Average mpg, weight, and horsepower for each model_year.

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['horsepower']=df['horsepower'].fillna(df['horsepower'].median())
summary_df = df.groupby('model year')[['mpg','weight','horsepower']].mean()
summary_df
# Out:
#                   mpg       weight  horsepower
# model year
# 70          17.689655  3372.793103  147.827586
# 71          21.250000  2995.428571  106.945335
# 72          18.714286  3237.714286  120.178571
# 73          17.100000  3419.025000  130.475000
# 74          22.703704  2877.925926   94.609977
# 75          20.266667  3176.800000  101.066667
# 76          21.573529  3078.735294  101.117647
# 77          23.375000  2997.357143  105.071429
# 78          24.061111  2861.805556   99.694444
# 79          25.093103  3055.344828  101.206897
# 80          33.696552  2436.655172   79.342716
# 81          30.334483  2522.931034   81.843772
# 82          31.709677  2453.548387   82.208690

# %% [markdown]
# Exporting Data
# Save a subset of the data containing only mpg, cylinders, horsepower, and weight
# for cars with mpg > 30 into a CSV file named high_mpg_cars.csv.

# %%
high_mpg_cars = df[df['mpg']>30][['mpg','cylinders','horsepower','weight']]
high_mpg_cars.to_csv('high_mpg_cars.csv',index=False)
high_mpg_cars.head()
# Out:
#       mpg  cylinders  horsepower  weight
# 53   31.0          4        65.0    1773
# 54   35.0          4        69.0    1613
# 129  31.0          4        67.0    1950
# 131  32.0          4        65.0    1836
# 144  31.0          4        52.0    1649

# %% [markdown]
# Identify potential outliers in the mpg column using the Interquartile Range (IQR)
# method. Specifically:
# ● Calculate the IQR for mpg.

# %%
Q1 = df['mpg'].quantile(0.25)
Q3 = df['mpg'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# np.float64(11.5)

# %% [markdown]
#  Define outliers as values less than Q1 - 1.5 * IQR or greater than Q3 +
# 1.5 * IQR.

# %%
lower_iqr = Q1 - 1.5 * IQR
upper_iqr = Q3 + 1.5 * IQR
print(lower_iqr,'\n',upper_iqr)
# Out:
# 0.25
#  46.25

# %%
outliers = df[(df['mpg'] < lower_iqr) | (df['mpg'] > upper_iqr)]
outliers_df = outliers[['car name','mpg','model year']]
outliers_df
# Out:
#       car name   mpg  model year
# 322  mazda glc  46.6          80
